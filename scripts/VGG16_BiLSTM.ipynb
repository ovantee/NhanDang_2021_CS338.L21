# %%
pip install efficientnet
# Out:
# Requirement already satisfied: efficientnet in /opt/conda/lib/python3.7/site-packages (1.1.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /opt/conda/lib/python3.7/site-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.7/site-packages (from efficientnet) (0.18.2)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.7/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.19.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.15.0)
# Requirement already satisfied: imageio>=2.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (2.9.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (8.2.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (1.1.1)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (3.4.2)
# Requirement already satisfied: scipy>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (1.6.3)
# Requirement already satisfied: networkx>=2.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (2.5)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (2021.7.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (0.10.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx>=2.0->scikit-image->efficientnet) (5.0.9)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from PIL import Image
import requests
from io import BytesIO
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from keras.layers import Activation, Dense,Flatten,Dropout
import efficientnet.tfkeras as efn 
import tensorflow
from nltk.corpus import wordnet as wn

# %%
target_size = (64, 64,3)
def load_and_proccess_image(id):
  # Load image, then scale and shift pixel values to [-0.5, 0.5]
  id=str(id)
  for i in range(12-len(id)):
    id='0'+id
  img = tensorflow.io.read_file('../input/coco2014/train2014/train2014/COCO_train2014_'+id+'.jpg')
  #img=img.resize((64,64))
  #im = img_to_array(img)
  #return im / 255 - 0.5
  img = tensorflow.image.decode_jpeg(img, channels=3)
  img = tensorflow.image.resize(img, (target_size[0],target_size[1]))
  img = efn.preprocess_input(img)
  return img

# %%
def wup_measure(word1,word2,similarity_threshold=0.9):
    word1_sem = wn.synsets(word1,pos=wn.NOUN)
    word2_sem = wn.synsets(word2,pos=wn.NOUN)
    score=0.0

    
    for x in word1_sem:
        for y in word2_sem:
            local_score=x.wup_similarity(y)
            if local_score > score:
                score=local_score

    
    if score < similarity_threshold:
        weight = 0.1
    else:
        weight = 1.0

    final_score = weight * score
    return final_score

def computeWups(answer_list,truth,similarity_threshold=0.9):
    score = 0
    for i in range(len(answer_list)):
        score += wup_measure(answer_list[i],truth[i],similarity_threshold)
    return (score / float(len(answer_list)))

# %% [markdown]
# ## load

# %%
train=pd.read_csv('../input/full-qa/data_full.csv')

# %%
train.columns=['question','object','id']

# %%
train_question=train['question'].values
train_answer=train['object'].values
train_id=train['id'].values

# %%
#train_question=pd.read_csv('../input/qa-coco/data/questions.csv').values
#train_answer=pd.read_csv('../input/qa-coco/data/answers.csv').values
#train_id=pd.read_csv('../input/qa-coco/data/img_ids.csv').values

# %%
#train_type=pd.read_csv('../input/nlp-question/train_type.csv')

# %%
#train_answer=np.concatenate( train_answer[:20000], axis=0 )
#train_question=np.concatenate( train_question[:20000], axis=0 )
#train_id=np.concatenate( train_id[:20000], axis=0 )

# %%
#train_answer=train_answer[:10000]
#train_question=train_question[:10000]
#train_id=train_id[:10000]

# %%
ims=[]
for i in range(len(train_id)):
  id=train_id[i]
  ims.append(load_and_proccess_image(id))

# %%
del_index=[]
for k in range(len(train_id)):
    if ims[k].shape!=(64,64,3):
        del_index.append(k)
        
import cv2
import numpy as np
for j in del_index:
    gray = ims[j]
    ims[j] = cv2.cvtColor(gray,cv2.COLOR_GRAY2RGB)

# %%
all_answer=np.unique(train_answer)

# %%
train_X_ims = ims

# %%
from tensorflow.keras.utils import to_categorical

train_answer_indices = [all_answer.tolist().index(a) for a in train_answer]

train_Y = to_categorical(train_answer_indices)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_question)
total_words = len(tokenizer.word_index) + 1

# %%
input_sequences = []
for line in train_question:
    token_list = tokenizer.texts_to_sequences([line])[0]
    input_sequences.append(token_list)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
# pad sequences 
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# %% [markdown]
# # Model

# %%
#Creating the CNN model for image processing
from tensorflow.keras.layers import Multiply
from tensorflow.keras.preprocessing.text import Tokenizer
import tensorflow as tf

CNN_Input=tf.keras.layers.Input(shape=(64,64,3))
CNN_model=tf.keras.applications.vgg16.VGG16(input_shape=(64,64,3), include_top=False,weights='imagenet')(CNN_Input)
CNN_model= Flatten(name='flatten')(CNN_model)
CNN_model= Dense(4096, activation='relu')(CNN_model)
CNN_model= Dense(4096, activation='relu')(CNN_model)
CNN_model= Dense(1024, activation='relu')(CNN_model)

#CNN_Input=tf.keras.layers.Input(shape=(64,64,3),name='image_input')
#CNN_model=tf.keras.models.Sequential()
#CNN_model=tf.keras.applications.mobilenet_v2.MobileNetV2(input_shape=(64,64,3), alpha=1.0, include_top=False,weights='imagenet', input_tensor=CNN_Input)(CNN_Input)
#CNN_model=tf.keras.layers.GlobalAveragePooling2D()(CNN_model)



vocab_size = len(tokenizer.word_index) + 1
shape=(vocab_size)

#Creating the RNN model for text processing
RNN_model=tf.keras.models.Sequential()

RNN_Input=tf.keras.layers.Input(shape=len(input_sequences[0]),name='text_input')
RNN_model=tf.keras.layers.Embedding(total_words, 100, input_length=max_sequence_len-1)(RNN_Input)
RNN_model=tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(256,stateful=False,return_sequences=True,recurrent_initializer='glorot_uniform'))(RNN_model)
RNN_model=tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(512,stateful=False,return_sequences=True,recurrent_initializer='glorot_uniform'))(RNN_model)
RNN_model=tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(512,stateful=False,return_sequences=False,recurrent_initializer='glorot_uniform'))(RNN_model)
RNN_model= Dense(1024, activation='tanh')(RNN_model)

# %%
from tensorflow.keras.layers import Multiply
out = Multiply()([CNN_model, RNN_model])
out = Dense(1000, activation='tanh')(out)
# num_answers will be defined below
out = Dense(len(all_answer), activation='softmax')(out)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
model = Model(inputs=[CNN_Input, RNN_Input], outputs=out)
model.compile(
  Adam(lr=2e-5),
  loss='categorical_crossentropy',
  metrics=['accuracy'],)

# %%
train_X_seqs=input_sequences

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, X_seqs_train, X_seqs_val, Y_train, Y_val = train_test_split(train_X_ims, train_X_seqs,train_Y ,test_size=0.1)

# %%
import tensorflow as tf
X_train=tf.stack(X_train)
X_val=tf.stack(X_val)

# %%
es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

# %%
history=model.fit(
  [X_train, X_seqs_train],
  Y_train,
  validation_data=([X_val, X_seqs_val], Y_val),
  shuffle=True,
  epochs=30,steps_per_epoch=100, validation_steps=100,callbacks=[es_callback] 
)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 45s 372ms/step - loss: 5.3019 - accuracy: 0.0672 - val_loss: 4.0535 - val_accuracy: 0.1292
# Epoch 2/30
# 100/100 [==============================] - 32s 325ms/step - loss: 3.9251 - accuracy: 0.1514 - val_loss: 3.6227 - val_accuracy: 0.1799
# Epoch 3/30
# 100/100 [==============================] - 32s 325ms/step - loss: 3.5428 - accuracy: 0.1970 - val_loss: 3.4172 - val_accuracy: 0.2201
# Epoch 4/30
# 100/100 [==============================] - 32s 324ms/step - loss: 3.3900 - accuracy: 0.2289 - val_loss: 3.2934 - val_accuracy: 0.2480
# Epoch 5/30
# 100/100 [==============================] - 32s 324ms/step - loss: 3.2467 - accuracy: 0.2561 - val_loss: 3.1821 - val_accuracy: 0.2698
# Epoch 6/30
# 100/100 [==============================] - 32s 324ms/step - loss: 3.1186 - accuracy: 0.2827 - val_loss: 3.0847 - val_accuracy: 0.2846
# Epoch 7/30
# 100/100 [==============================] - 32s 324ms/step - loss: 2.9858 - accuracy: 0.3127 - val_loss: 3.0091 - val_accuracy: 0.3007
# Epoch 8/30
# 100/100 [==============================] - 32s 324ms/step - loss: 2.8575 - accuracy: 0.3340 - val_loss: 2.9364 - val_accuracy: 0.3111
# Epoch 9/30
# 100/100 [==============================] - 32s 324ms/step - loss: 2.8018 - accuracy: 0.3471 - val_loss: 2.9024 - val_accuracy: 0.3295
# Epoch 10/30
# 100/100 [==============================] - 32s 324ms/step - loss: 2.6669 - accuracy: 0.3760 - val_loss: 2.8427 - val_accuracy: 0.3372
# Epoch 11/30
# 100/100 [==============================] - 32s 324ms/step - loss: 2.6039 - accuracy: 0.3924 - val_loss: 2.7747 - val_accuracy: 0.3430
# Epoch 12/30
# 100/100 [==============================] - 32s 324ms/step - loss: 2.4799 - accuracy: 0.4195 - val_loss: 2.7471 - val_accuracy: 0.3493
# Epoch 13/30
# 100/100 [==============================] - 32s 324ms/step - loss: 2.3945 - accuracy: 0.4439 - val_loss: 2.7328 - val_accuracy: 0.3530
# Epoch 14/30
# 100/100 [==============================] - 32s 324ms/step - loss: 2.2926 - accuracy: 0.4628 - val_loss: 2.6973 - val_accuracy: 0.3503
# Epoch 15/30
# 100/100 [==============================] - 32s 324ms/step - loss: 2.2274 - accuracy: 0.4803 - val_loss: 2.6475 - val_accuracy: 0.3685
# Epoch 16/30
# 100/100 [==============================] - 32s 323ms/step - loss: 2.1133 - accuracy: 0.5078 - val_loss: 2.6323 - val_accuracy: 0.3735
# Epoch 17/30
# 100/100 [==============================] - 32s 324ms/step - loss: 2.0174 - accuracy: 0.5361 - val_loss: 2.6113 - val_accuracy: 0.3772
# Epoch 18/30
# 100/100 [==============================] - 32s 323ms/step - loss: 1.9256 - accuracy: 0.5576 - val_loss: 2.5918 - val_accuracy: 0.3856
# Epoch 19/30
# 100/100 [==============================] - 32s 323ms/step - loss: 1.8143 - accuracy: 0.5870 - val_loss: 2.5706 - val_accuracy: 0.3789
# Epoch 20/30
# 100/100 [==============================] - 32s 323ms/step - loss: 1.6945 - accuracy: 0.6201 - val_loss: 2.5626 - val_accuracy: 0.3859
# Epoch 21/30
# 100/100 [==============================] - 32s 323ms/step - loss: 1.6076 - accuracy: 0.6482 - val_loss: 2.5658 - val_accuracy: 0.3926
# Epoch 22/30
# 100/100 [==============================] - 32s 324ms/step - loss: 1.4979 - accuracy: 0.6771 - val_loss: 2.5603 - val_accuracy: 0.3899
# Epoch 23/30
# 100/100 [==============================] - 32s 324ms/step - loss: 1.4251 - accuracy: 0.6936 - val_loss: 2.5560 - val_accuracy: 0.3883
# Epoch 24/30
# 100/100 [==============================] - 32s 324ms/step - loss: 1.3153 - accuracy: 0.7292 - val_loss: 2.5415 - val_accuracy: 0.3993
# Epoch 25/30
# 100/100 [==============================] - 32s 323ms/step - loss: 1.1924 - accuracy: 0.7585 - val_loss: 2.5473 - val_accuracy: 0.3980
# Epoch 26/30
# 100/100 [==============================] - 32s 324ms/step - loss: 1.1289 - accuracy: 0.7784 - val_loss: 2.5473 - val_accuracy: 0.3919
# Epoch 27/30
# 100/100 [==============================] - 32s 324ms/step - loss: 1.0375 - accuracy: 0.8023 - val_loss: 2.5570 - val_accuracy: 0.3970

# %%
model = tf.keras.models.load_model('../input/model-qa-all/all_VGG.h5')

# %%
model.save('all_VGG.h5')
import pickle
pickle.dump(tokenizer, open("all_VGG.pkl", "wb"))

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
pred1=np.argmax(model.predict([X_val[:2000],X_seqs_val[:2000]],steps=1), axis=1)
pred2=np.argmax(model.predict([X_val[2000:],X_seqs_val[2000:]],steps=1), axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-347405ef82c3> in <module>
#       2 pred2=np.argmax(model.predict([X_val[2000:],X_seqs_val[2000:]],steps=1), axis=1)
#       3
# ----> 4 pred=pred1+pred2
#
# ValueError: operands could not be broadcast together with shapes (2000,) (980,)

# %%
pred=np.concatenate((pred1, pred2))

# %%
y_pred=[]
y_val=[]
for p in range(len(pred)):
    y_pred.append(all_answer[pred[p]])
    y_val.append(all_answer[np.argmax(Y_val[p])])

# %%
computeWups(y_pred,y_val,0.9)
# Out:
# 0.8237134234075701

# %%
computeWups(y_pred,y_val,0.0)
# Out:
# 0.9411317274328153
